# %%
from spiceracs.utils import gettable
import matplotlib.pyplot as plt
import seaborn as sns
# %config Completer.use_jedi = False

# %%
tab, name = gettable('/avatar/athomson/cubes/8585/RACS_test4_1.05_1049-31A/moments', 'p*mu*linmos_comp')
# Out:
# Getting table data from /avatar/athomson/cubes/8585/RACS_test4_1.05_1049-31A/moments/image.restored.p.SB8583.mu.RACS_test4_1.05_1049-31A.linmos_comp.xml...

# %%
len(tab)
# Out:
# 162

# %%
plt.figure()
sns.distplot(tab['local_rms'], hist=True, kde=False, bins = 15, color = 'red', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, label='local_rms')
sns.distplot(tab['background'], hist=True, kde=False, bins = 15, color = 'blue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, label='backround')

plt.xlabel('Flux (Jy/Beam)')
plt.ylabel('Count')
plt.legend()
# Out:
# /home/athomson/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/athomson/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
from matplotlib.colors import LogNorm

# %%
# %matplotlib inline

# %%
#plt.figure()
(sns.jointplot(np.array(tab['local_rms']), np.array(tab['background']), kind="kde", space=0,)
    ).plot_joint(sns.scatterplot).set_axis_labels("local_rms", "background")
plt.tight_layout
#plt.scatter(tab['local_rms'], tab['background'], marker='.', c=tab['peak_flux'])
#plt.colorbar()
#plt.xlabel('test')
#plt.ylabel('')
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
plt.figure()
sns.distplot(tab['local_rms'], hist=True, kde=True, bins = 10, color = 'red', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4}, label='local_rms', )
#sns.distplot(tab['background'], hist=True, kde=True, bins = 15, color = 'blue', 
#             hist_kws={'edgecolor':'black'},
#             kde_kws={'linewidth': 4}, label='backround', )
#
plt.xlabel('Flux (Jy/Beam)')
plt.ylabel('Count')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-072b84fe4c4c> in <module>
#       2 sns.distplot(tab['local_rms'], hist=True, kde=True, bins = 10, color = 'red',
#       3              hist_kws={'edgecolor':'black'},
# ----> 4              kde_kws={'linewidth': 4}, label='local_rms', )
#       5 #sns.distplot(tab['background'], hist=True, kde=True, bins = 15, color = 'blue',
#       6 #             hist_kws={'edgecolor':'black'},
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
# ...

# %%
# %matplotlib notebook

# %%
plt.figure()
plt.scatter(tab['local_rms'], tab['background'], c=tab['peak_flux'], cmap='plasma_r')
cbar = plt.colorbar()
cbar.set_label('peak_flux')
plt.xlabel('local_rms')
plt.ylabel('background')
# Out:
# Text(0, 0.5, 'background')

# %%
plt.figure()
plt.scatter(tab['int_flux'], tab['local_rms'])
plt.xlabel('int_flux')
plt.ylabel('local_rms')
# Out:
# Text(0, 0.5, 'local_rms')

# %%
plt.figure()
plt.scatter(tab['peak_flux'], tab['background'], c = tab['local_rms'], cmap='viridis')
plt.xlabel('peak_flux')
plt.ylabel('background')
# Out:
# Text(0, 0.5, 'background')

# %%
len(tab[tab['local_rms'] < 0.000635])
# Out:
# 49

# %%
plt.figure()
plt.scatter(tab['peak_flux'], tab['local_rms'], c = tab['background'], marker='.')
sns.kdeplot(np.array(tab['peak_flux']), np.array(tab['local_rms']))
plt.xlabel('peak_flux')
plt.ylabel('local_rms')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3a724ef56528> in <module>
#       1 plt.figure()
#       2 plt.scatter(tab['peak_flux'], tab['local_rms'], c = tab['background'], marker='.')
# ----> 3 sns.kdeplot(np.array(tab['peak_flux']), np.array(tab['local_rms']))
#       4 plt.xlabel('peak_flux')
#       5 plt.ylabel('local_rms')
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     685         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     686                                 kernel, bw, gridsize, cut, clip, legend,
# --> 687                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     688     else:
# ...

# %%
#plt.figure()
(sns.jointplot(np.array(tab['peak_flux']), np.array(tab['background']), kind="kde", space=0,)
    ).plot_joint(sns.scatterplot).set_axis_labels("peal_flux", "background")
plt.tight_layout
#plt.scatter(tab['local_rms'], tab['background'], marker='.', c=tab['peak_flux'])
#plt.colorbar()
#plt.xlabel('test')
#plt.ylabel('')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
(sns.jointplot(np.array(tab['int_flux']), np.array(tab['background']), kind="kde", space=0,)
    ).plot_joint(sns.scatterplot).set_axis_labels("peal_flux", "background")
plt.tight_layout
# Out:
# <img src="data:image/png;base64,..." width="432">
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>
